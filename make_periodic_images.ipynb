# %% [markdown]
# ## Make periodic images of MD output

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
path = "C:/Users/Sachith/Desktop/work_oh/Alex/" #file path
#st = 432             #start writing at st
#endstep = 445   #stop writing at endstep

# %%
f=open(path +'/input_data.dat','r')
lines=f.readlines()
for line in lines[0:]:
    data=line.split()
    print(data)
    if data[0]=='natoms:':
        natoms = int(data[1])
    if data[0]=='nonmvat:':
        nonmvat = int(data[1])
    if data[0]=='nsteps:':
        nsteps = int(data[1])
    if data[0]=='nmovingatoms:':
        nmovingatoms = int(data[1])
    if data[0]=='MDRestartFrequency:':
        MDRestartFrequency = int(data[1])
    if data[0]=='dt:':
        dt = float(data[1])
    if data[0]=='noh:':
        noh = int(data[1])
    if data[0]=='nwater:':
        nwater = int(data[1])
    if data[0]=='nox:':
        nox = int(data[1])
    if data[0]=='nhy:':
        nhy = int(data[1])
    if data[0]=='xbox:':
        xbox = float(data[1])
    if data[0]=='ybox:':
        ybox = float(data[1])
    if data[0]=='zbox:':
        zbox = float(data[1]) 
nstep = nsteps
# Out:
# ['total_time:', '10.0']
# ['nsteps:', '10000']
# ['natoms:', '533']
# ['nonmvat:', '433']
# ['nmovingatoms:', '100']
# ['MDRestartFrequency:', '10']
# ['dt:', '1']
# ['noh:', '2']
# ['nwater:', '32']
# ['nox:', '34']
# ['nhy:', '66']
# ['xbox:', '20.244']
# ['ybox:', '13.3552']
# ['zbox:', '40.0']

# %%
atom= ['Non']*(natoms)
x_coor = np.empty(nsteps*natoms).reshape(natoms,nsteps)
y_coor = np.empty(nsteps*natoms).reshape(natoms,nsteps)
z_coor = np.empty(nsteps*natoms).reshape(natoms,nsteps)

# %%
jj=0
kk= st*(natoms+2)
f=open(path +'/geo_end.xyz','r')
lines=f.readlines()
while (jj+st) < endstep:
    io=0
    for line in lines[kk:(kk+natoms+2)]:
        data=line.split()
        if len(data)>3:
            atom[io] = data[0]
            x_coor[io][jj]=float(data[1])
            y_coor[io][jj]=float(data[2])
            z_coor[io][jj]=float(data[3])
            print(io,jj,x_coor[io][jj])
            io = io+1

    kk=kk+natoms+2
    jj=jj+1
# Out:
# 0 0 3.1551
# 1 0 3.1787
# 2 0 4.4348
# 3 0 1.89964
# 4 0 1.89608
# 5 0 4.4329
# 6 0 1.92189
# 7 0 -1.92047
# 8 0 0.61804
# 9 0 -0.63736
# 10 0 0.59503
# 11 0 3.13534
# 12 0 5.69176
# 13 0 0.6704
# 14 0 0.64324
# 15 0 -0.64192
# 16 0 4.45307
# 17 0 -0.61261
# 18 0 5.71322
# 19 0 5.67655
# 20 0 4.41167
# 21 0 -1.89426
# 22 0 -3.18139
# 23 0 -3.17648
# 24 0 -3.14913
# 25 0 -1.94554
# 26 0 -0.66941
# 27 0 3.20269
# 28 0 5.73282
# 29 0 -1.86566
# 30 0 -3.20854
# 31 0 1.87102
# 32 0 -1.89633
# 33 0 0.63991
# 34 0 3.17512
# 35 0 5.71044
# 36 0 -0.60898
# 37 0 1.92444
# 38 0 4.45755
# 39 0 -3.14309
# 40 0 -1.92809
# 41 0 0.61022
# 42 0 3.14824
# 43 0 5.68778
# 44 0 4.48318
# 45 0 1.95355
# 46 0 -3.10908
# 47 0 -0.57765
# 48 0 -4.43861
# 49 0 -4.43742
# 50 0 -4.46403
# 51 0 -5.66657
# 52 0 -5.70656
# 53 0 -5.70149
# 54 0 -5.68007
# 55 0 -4.48028
# 56 0 -4.41736
# 57 0 -5.78238
# 58 0 -5.72256
# 59 0 -4.4988
# 60 0 -5.65887
# 61 0 -4.37705
# 62 0 -3.13893
# 63 0 -1.85494
# 64 0 -0.61147
# ...

# %%
atom2 = atom[nonmvat:]         # remove frozen atoms
x_coor2 = x_coor[nonmvat: , :]
y_coor2 = y_coor[nonmvat: , :]
z_coor2 = z_coor[nonmvat: , :]

# %%
print(x_coor2[1][200])
len(x_coor2)
# Out:
# 0.0
# 62

# %%
ll = 0
natoms2 = natoms-nonmvat
f=open(path +'/hopp_perodic.xyz','w')
while ll < (endstep-st) :
    kk = 0
    print(natoms2*9,file =f)
    print('MD iter:' , ll ,file =f)
    while kk < natoms2 :
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]),'{0: >#016.8f}'.format(y_coor2[kk][ll]),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]),'{0: >#016.8f}'.format(y_coor2[kk][ll]+ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]+xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]+ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]+xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]+xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]-ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]),'{0: >#016.8f}'.format(y_coor2[kk][ll]-ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]-xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]-ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]-xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]-xbox),'{0: >#016.8f}'.format(y_coor2[kk][ll]+ybox),'{0: >#016.8f}'.format(z_coor2[kk][ll]),file =f )
        
        print('{:3}'.format(atom2[kk]),'{0: >#016.8f}'.format(x_coor2[kk][ll]),'{0: >#016.8f}'.format(y_coor2[kk][ll]),'{0: >#016.8f}'.format(z_coor2[kk][ll]))
        
        kk=kk+1
    ll = ll+1
f.close()
# Out:
# O         3.13786885      -4.36964036       3.46918035
# H         3.92837169      -4.94006996       3.39099968
# H        -8.02236921      -2.16810875       7.00055029
# O         1.77569182      -4.81882762       6.10718580
# H         4.86411741       1.53703345       5.32789279
# H         1.99029080      -4.24754478       6.86514192
# O         1.93148898      -2.08863798       5.27093403
# H         1.80040354      -3.06972655       5.18599076
# H         1.26050653      -1.73524015       4.67993960
# O        -3.41817395      10.80749377       3.92427980
# H        -3.30927604      11.00155673       2.95405800
# H        -4.04856058      -1.92248934       4.38110179
# O         4.01298405      -1.79921525       3.63633088
# H         3.60877665      -2.63534080       3.32848770
# H         4.39651754      -1.95546002       4.52640544
# O         4.03747192       6.82422712       6.26502663
# H         2.57245237      -5.45297787       6.05404659
# ...
